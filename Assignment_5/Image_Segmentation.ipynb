# %%
import numpy as np
import matplotlib.pyplot as plt
from data_utils import load_images, load_ground_truth
from visuals import plot_img_with_gnd, plot_images_truths
from normalized_cut import NormalizedCut
from k_means import CustomKMeans

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
PATH = 'BSR/BSDS500/data/'

x_train, x_val, x_test = load_images(PATH)
y_train, y_val, y_test = load_ground_truth(PATH)

# %% [markdown]
# ## Plot image vs ground truth

# %%
plot_img_with_gnd(x_train[0], y_train[0]['groundTruth'])

# %%
plot_images_truths(x_train[0:2], y_train[0:2])

# %%
# train
k_means = [3, 5, 7, 9, 11]
cl = CustomKMeans(k_means)
# type(x_train)
cl.train(x_train, y_train, verbose=False)
# Out:
# 0 0.3983000684487555 0.2684008497181646
# 1 0.5545452241138709 0.44004161631496264
# 2 0.366608849803863 0.23405185768016185
# 3 0.3935160847558944 0.25880757998423143
# 4 0.27409997771499006 0.09835676216673721
# 5 0.3605678241658991 0.12897543029265848
# 6 0.35835324854139344 0.12970492561868802
# 7 0.34692045192928805 0.22396913549612116
# 8 0.5820908653469553 0.5164779322375593
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0a7f45eab447> in <module>
#       3 cl = CustomKMeans()
#       4 # type(x_train)
# ----> 5 cl.train(x_train, y_train, k_means)
#
# /media/youssef/Joe/College/4th year/1st semester/projects and assigmnets/Data mining/Assignments/Assignment_5/cluster_algorithm.py in train(self, x_train, y_train, k_means)
#      11     def train(self, x_train, y_train, k_means, verbose=False):
#      12         for i in range(len(x_train)):
# ...
